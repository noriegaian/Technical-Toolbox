# %%
#Purpose: We're going to use LDA (latent Dirichlet allocation) to analyze the
#kiva dataset (requests for loans) and to extrapolate relevant topics from
#the loan requests

# %%
import pandas as pd

# %%
#import kiva dataset (requested loans)
kiva_df = pd.read_csv("kiva_cleaned.csv")

# %%
kiva_df.info()
#observations: nearly 7000 rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6818 entries, 0 to 6817
# Data columns (total 9 columns):
# loan_id        6818 non-null int64
# status         6818 non-null object
# sector         6818 non-null object
# en             6818 non-null object
# country        6818 non-null object
# gender         6818 non-null object
# loan_amount    6818 non-null float64
# nonpayment     6818 non-null object
# en_clean       6802 non-null object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 479.5+ KB

# %%
#there happen to be some rows with nothing in them...remove them
kiva_df = kiva_df.dropna()
kiva_df = kiva_df.reset_index(drop=True)

# %%
kiva_df.head()
#en_clean is our text field of primary interest
# Out:
#    loan_id     status        sector  \
# 0        0  defaulted   Agriculture
# 1        1  defaulted          Food
# 2        2  defaulted          Food
# 3        3  defaulted      Services
# 4        4  defaulted  Construction
#
#                                                   en country gender  \
# 0  <i>This description is written by Rowland Amul...   Kenya      M
# 1  <i>This description is written by Rowland Amul...   Kenya      F
# 2  <i>This description was written by Richard Maz...   Kenya      M
# 3  <i>This description was written by Rowland Amu...   Kenya      F
# 4  <i>This description was written by Rowland Amu...   Kenya      M
#
#    loan_amount nonpayment                                           en_clean
# 0        500.0     lender  Robert, 40, is married and has 6 children. In ...
# 1        500.0     lender  Petronilla, 30, was deserted by her husband an...
# 2        500.0     lender  Tom Mung'ahu, 45, is married and has 6 childre...
# 3        500.0     lender  Benedina, 42, is married and has 4 girls. In a...
# 4        500.0     lender  Vincent Ondego 40, is married and has 8 childr...

# %%
#import text mining packages
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re
import unidecode

#define stop words (notice we include spanish due to its df presence)
stop_words = set(stopwords.words('english') + stopwords.words('spanish'))

#lemmatizer
lemmer = WordNetLemmatizer()

#preprocessing function
def preprocess(x):
    x = x.lower() #lower case everything
    
    x = re.sub(r'[^\w\s]', '', x) #remove any punctuation
    
    x = unidecode.unidecode(x)
    
    x = re.sub(r'\d+', '', x) #remove any numbers
    
    x = [lemmer.lemmatize(w) for w in x.split() if w not in stop_words]
        
    return ' '.join(x)

kiva_df['en_clean_pre'] = kiva_df['en_clean'].apply(preprocess)

# %%
#check out first couple rows now
kiva_df.head(2)
#observations: notice that en_clean_pre now shows post-preprocessing (we have
#a list of terms)
# Out:
#    loan_id     status       sector  \
# 0        0  defaulted  Agriculture
# 1        1  defaulted         Food
#
#                                                   en country gender  \
# 0  <i>This description is written by Rowland Amul...   Kenya      M
# 1  <i>This description is written by Rowland Amul...   Kenya      F
#
#    loan_amount nonpayment                                           en_clean  \
# 0        500.0     lender  Robert, 40, is married and has 6 children. In ...
# 1        500.0     lender  Petronilla, 30, was deserted by her husband an...
#
#                                         en_clean_pre
# 0  robert married child addition family take care...
# 1  petronilla deserted husband responsible upbrin...

# %%
#original text field
kiva_df.iloc[0, :].en_clean
# Out:
# 'Robert, 40, is married and has 6 children. In addition to his family of 8, he takes care of his mother and 5 brothers. Robert started by planting vegetables and selling at the local market. He then diversified with a tea nursery which is more profitable. Given a loan of $500, Robert will be able to improve his activities by buying fertilizers, pesticides, a pump and seedlings. The pump will remove the uncertainties of the weather. The current capital in his venture is Ksh 10500 or $150, which does not allow Robert to maximize his potential. Robert completed high school and has never got employment. He got apprentice training from a tea extension officer. He is a go getter, and his main hobby is teaching music.'

# %%
#new (preprocessed) text field
kiva_df.iloc[0, :].en_clean_pre
# Out:
# 'robert married child addition family take care mother brother robert started planting vegetable selling local market diversified tea nursery profitable given loan robert able improve activity buying fertilizer pesticide pump seedling pump remove uncertainty weather current capital venture ksh allow robert maximize potential robert completed high school never got employment got apprentice training tea extension officer go getter main hobby teaching music'

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

#set up TF-IDF vectorizer
vectorizer = TfidfVectorizer(max_df = 0.5, min_df = 0.05,
                            max_features = 1000, ngram_range = [1,3])

#parameters: max_df is the max % of documents a word can be in
            #min_df is the min % of documents a word can be in
            #max_features means only keep the x amount of frequent words
            #ngram_range specifies what level of n-grams to keep
            
#pass in our data
dtm = vectorizer.fit_transform(kiva_df['en_clean_pre'])

# %%
dtm.shape #observations: 270 features were kept
# Out:
# (6802, 270)

# %%
#let's look at what these features were
vectorizer.get_feature_names()
#notice quite a few interesting words, some n-grams as well
# Out:
# ['able',
#  'active',
#  'active member',
#  'activity',
#  'add',
#  'additional',
#  'age',
#  'ago',
#  'allow',
#  'also',
#  'always',
#  'amount',
#  'another',
#  'applied',
#  'applied loan',
#  'area',
#  'attend',
#  'back',
#  'basic',
#  'bean',
#  'began',
#  'belief',
#  'better',
#  'born',
#  'bought',
#  'boy',
#  'business selling',
#  'buy',
#  'buying',
#  'capital',
#  'care',
#  'cement',
#  'child school',
#  'childrens',
#  'church',
#  'city',
#  'client',
#  'clothes',
#  'clothing',
#  'college',
#  'community',
#  'continue',
#  'cost',
#  'could',
#  'cow',
#  'currently',
#  'customer',
#  'dairy',
#  'dairy cow',
#  'daughter',
#  'day',
#  'decided',
#  'demand',
#  'different',
#  'domingo',
#  'dominican',
#  'dream',
#  'due',
#  'earn',
#  'educate',
#  'education',
#  'enable',
#  'enough',
#  'entrepreneur',
#  'every',
#  'every day',
#  'expand',
#  'expand business',
#  'expense',
#  'experience',
#  'explains',
#  'family',
#  'farm',
#  'farmer',
#  'farming',
#  'father',
#  'fee',
#  'feed',
#  'first',
#  'first loan',
#  'five',
#  'five child',
#  'food',
#  'four',
#  'four child',
#  'friend',
#  'fruit',
#  'fund',
#  'future',
#  'get',
#  'girl',
#  'give',
#  'given',
#  'go',
#  'goal',
#  'good',
#  'great',
#  'grocery',
#  'group',
#  'grow',
#  'growing',
#  'hard',
#  'hardworking',
#  'help',
#  'high',
#  'home',
#  'hope',
#  'house',
#  'household',
#  'husband',
#  'improve',
#  'income',
#  'increase',
#  'intends',
#  'inventory',
#  'invest',
#  'item',
#  'job',
#  'keep',
#  'kenya',
#  'kiva',
#  'lack',
#  'land',
#  'large',
#  'last',
#  'left',
#  'life',
#  'like',
#  'little',
#  'live',
#  'living',
#  'loan buy',
#  'loan purchase',
#  'loan usd',
#  'local',
#  'located',
#  'lot',
#  'made',
#  'main',
#  'maize',
#  'make',
#  'making',
#  'many',
#  'market',
#  'married',
#  'married child',
#  'material',
#  'meet',
#  'member',
#  'merchandise',
#  'milk',
#  'money',
#  'month',
#  'monthly',
#  'mother',
#  'much',
#  'nairobi',
#  'need',
#  'need loan',
#  'neighborhood',
#  'new',
#  'next',
#  'offer',
#  'old',
#  'old married',
#  'one',
#  'open',
#  'operates',
#  'opportunity',
#  'order',
#  'owns',
#  'parent',
#  'part',
#  'pay',
#  'people',
#  'per',
#  'period',
#  'person',
#  'plan',
#  'pm',
#  'price',
#  'primary',
#  'primary school',
#  'produce',
#  'product',
#  'profit',
#  'provide',
#  'purchase',
#  'quality',
#  'receive',
#  'rent',
#  'repay',
#  'repay loan',
#  'requesting',
#  'requesting loan',
#  'rice',
#  'run',
#  'running',
#  'sale',
#  'santo',
#  'santo domingo',
#  'save',
#  'saving',
#  'say',
#  'school',
#  'school fee',
#  'season',
#  'second',
#  'second loan',
#  'secondary',
#  'secondary school',
#  'selling',
#  'service',
#  'shoe',
#  'shop',
#  'since',
#  'single',
#  'single mother',
#  'six',
#  'small',
#  'small business',
#  'sold',
#  'source',
#  'source income',
#  'start',
#  'started',
#  'started business',
#  'still',
#  'stock',
#  'store',
#  'study',
#  'supply',
#  'support',
#  'support family',
#  'take',
#  'take care',
#  'therefore',
#  'three',
#  'three child',
#  'time',
#  'together',
#  'town',
#  'training',
#  'two',
#  'two child',
#  'two year',
#  'usd',
#  'use',
#  'use loan',
#  'used',
#  'variety',
#  'vegetable',
#  'want',
#  'way',
#  'week',
#  'well',
#  'wholesale',
#  'wife',
#  'within',
#  'woman',
#  'woman group',
#  'work',
#  'working',
#  'would',
#  'would like',
#  'year ago',
#  'year old',
#  'year old married',
#  'yearold',
#  'young']

# %%
#now we can apply LDA
from sklearn.decomposition import LatentDirichletAllocation

lda_model = LatentDirichletAllocation(n_components = 20, doc_topic_prior=None,
                                     topic_word_prior= None, max_iter=200,
                                     learning_method="batch", random_state=1024,
                                     n_jobs=2, verbose=0)

#n_components is # of topics we want to identify

lda_output = lda_model.fit(dtm)

# %%
#check how well it works, look at log likelihood
lda_model.score(dtm)
#observations: (higher values are better)
# Out:
# -223934.59825649523

# %%
#perplexity score as well
lda_model.perplexity(dtm)
#observations: (lower values are better)
# Out:
# 545.3753103152957

# %%
#get theta matrix (by transforming the tdm matrix)
theta = pd.DataFrame(lda_model.transform(dtm))

# %%
theta.head()
#observations: columns are our 20 topics and rows are all our documents
#entry is saying what was the membership of that topic in that document
#ex: topic 0 was hardly at all in document 0
#ex: topic 7 was alot in document 4 (0.82)
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.008651  0.008651  0.008651  0.008651  0.008651  0.008651  0.008651
# 1  0.007398  0.007398  0.007398  0.007398  0.007398  0.007398  0.007398
# 2  0.008250  0.008250  0.008250  0.008250  0.008250  0.008250  0.243813
# 3  0.010299  0.010299  0.010299  0.010299  0.010299  0.010299  0.010299
# 4  0.009396  0.009396  0.009396  0.009396  0.009396  0.009396  0.009396
#
#           7         8         9        10        11        12        13  \
# 0  0.008651  0.008651  0.008651  0.008651  0.008651  0.008651  0.008651
# 1  0.029796  0.007398  0.007398  0.007398  0.007398  0.007398  0.007398
# 2  0.008250  0.008250  0.008250  0.008250  0.008250  0.008250  0.607688
# 3  0.010299  0.010299  0.010299  0.010299  0.010299  0.010299  0.010299
# 4  0.821479  0.009396  0.009396  0.009396  0.009396  0.009396  0.009396
#
#          14        15        16        17        18        19
# 0  0.008651  0.008651  0.835625  0.008651  0.008651  0.008651
# 1  0.007398  0.007398  0.007398  0.837044  0.007398  0.007398
# 2  0.008250  0.008250  0.008250  0.008250  0.008250  0.008250
# 3  0.010299  0.010299  0.804310  0.010299  0.010299  0.010299
# 4  0.009396  0.009396  0.009396  0.009396  0.009396  0.009396

# %%
#get beta matrix
beta = pd.DataFrame(lda_model.components_)

# %%
beta.head()
#observations: shows us how much each word is in each topic
#words are columns and rows are topics
# Out:
#          0         1     2         3         4         5         6    \
# 0   0.050000  0.050000  0.05  0.050000  0.050000  0.050000  0.050000
# 1   0.050000  0.050000  0.05  0.050000  0.050000  0.050000  0.050000
# 2  14.300158  0.050000  0.05  0.241028  0.223391  2.343714  0.050000
# 3   4.316497  0.730651  0.05  3.171225  4.121851  0.836469  1.629435
# 4  34.877355  0.740758  0.05  4.790612  3.798218  6.497496  4.567630
#
#          7          8          9    ...   260        261        262  \
# 0   0.050000   0.050000   0.050000  ...  0.05   0.050000   0.050000
# 1   0.050000   0.050000   0.050000  ...  0.05   0.050000   0.050000
# 2   2.091495   0.050000  13.999800  ...  0.05  10.160350   5.554609
# 3   7.812080   3.326142   6.754259  ...  0.05   8.038774   4.762683
# 4  37.430035  16.636247  45.824983  ...  0.05  33.452215  10.244747
#
#          263        264        265        266        267       268       269
# 0   0.050000   0.050000   0.050000   0.050000   0.050000  0.050000  0.050000
# 1   0.050000   0.050000   0.050000   0.050000   0.050000  0.050000  0.050000
# 2   3.237253   0.946131   1.007789   2.001923   0.050000  1.167519  0.443704
# 3   2.535545   2.016488   5.113907   7.684086   1.222312  4.539481  3.665516
# 4  23.988039  11.035844  34.714183  58.693398  11.685873  1.703330  4.462702
#
# [5 rows x 270 columns]

# %%
#this code will give us which words are in which topics nicely
feature_names = vectorizer.get_feature_names()
termss = list()
for topic_id, topic in enumerate(lda_model.components_):
    terms = ' '.join([feature_names[i] for i in topic.argsort()[:-6 - 1:-1]])
    termss.append(terms)
    
topic_summary = pd.DataFrame({'TopicID': range(0, len(termss)), 'Terms': termss})

# %%
topic_summary
#observations: here are our 20 topics and the top 6 words in that topic to
#give us an idea of what they are about
#ex: topic 1 seems to be about grocery products, topic 3 seems like the DR
# Out:
#     TopicID                                              Terms
# 0         0      fee applied farming dairy repay married child
# 1         1                 rice bean grocery store basic milk
# 2         2   second second loan first loan first kiva product
# 3         3  santo domingo santo domingo community entrepre...
# 4         4        product home store merchandise old year old
# 5         5      expand expand business father living fee need
# 6         6  stock primary school able primary school increase
# 7         7          group usd member school woman group woman
# 8         8  boy entrepreneur community husband product cus...
# 9         9      fee applied farming dairy repay married child
# 10       10              dairy cow milk group dairy cow member
# 11       11                 rice land farm hope farming farmer
# 12       12             group life small hope dominican member
# 13       13                  work pm home help product husband
# 14       14  yearold located married clothes married child ...
# 15       15  entrepreneur clothing community woman explains...
# 16       16           care kenya service also take care within
# 17       17  school requesting requesting loan family buy lack
# 18       18    member another together help receive repay loan
# 19       19  clothes business selling selling price new exp...
