# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('groceries.csv')

# %%
df.info() #nearly 10,000 transactions/baskets
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9835 entries, 0 to 9834
# Columns: 169 entries, frankfurter to bags
# dtypes: bool(169)
# memory usage: 1.6 MB

# %%
#let's look at a couple
df.head()
#observations: notice that each transaction is a row and each item is a column - this is the format that mlxtend likes
# Out:
#    frankfurter  sausage  liver loaf    ham   meat  finished products  \
# 0        False    False       False  False  False              False
# 1        False    False       False  False  False              False
# 2        False    False       False  False  False              False
# 3        False    False       False  False  False              False
# 4        False    False       False  False  False              False
#
#    organic sausage  chicken  turkey   pork  ...  candles  light bulbs  \
# 0            False    False   False  False  ...    False        False
# 1            False    False   False  False  ...    False        False
# 2            False    False   False  False  ...    False        False
# 3            False    False   False  False  ...    False        False
# 4            False    False   False  False  ...    False        False
#
#    sound storage medium  newspapers  photo/film  pot plants  \
# 0                 False       False       False       False
# 1                 False       False       False       False
# 2                 False       False       False       False
# 3                 False       False       False       False
# 4                 False       False       False       False
#
#    flower soil/fertilizer  flower (seeds)  shopping bags   bags
# 0                   False           False          False  False
# 1                   False           False          False  False
# 2                   False           False          False  False
# 3                   False           False          False  False
# 4                   False           False          False  False
#
# [5 rows x 169 columns]

# %%
#download apriori from mlxtend library
from mlxtend.frequent_patterns import apriori

#fair warning - this was initially very memory-intensive to run (not sure why)
frequent_itemsets = apriori(df, min_support=0.001, use_colnames=True) #use apriori algorithm to obtain frequent itemsets

# %%
frequent_itemsets.info() #13000 rows with 2 columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13492 entries, 0 to 13491
# Data columns (total 2 columns):
# support     13492 non-null float64
# itemsets    13492 non-null object
# dtypes: float64(1), object(1)
# memory usage: 210.9+ KB

# %%
frequent_itemsets.head()
#observations: what this is saying is that sausage has a support of about 9%, etc.
# Out:
#     support       itemsets
# 0  0.058973  (frankfurter)
# 1  0.093950      (sausage)
# 2  0.005084   (liver loaf)
# 3  0.026029          (ham)
# 4  0.025826         (meat)

# %%
#let's check the end of the frequent_itemsets
frequent_itemsets.tail()
#observations: notice that these itemsets have more items in them
# Out:
#         support                                           itemsets
# 13487  0.001118  (whipped/sour cream, root vegetables, yogurt, ...
# 13488  0.001322  (root vegetables, yogurt, tropical fruit, othe...
# 13489  0.001017  (root vegetables, yogurt, oil, tropical fruit,...
# 13490  0.001118  (root vegetables, yogurt, tropical fruit, othe...
# 13491  0.001017  (domestic eggs, yogurt, tropical fruit, other ...

# %%
frequent_itemsets.sort_values(by=['support'], ascending=False).head()
#observations: whole milk has the highest support (i.e., most prevalent itemset out of all the transactions)
# Out:
#      support            itemsets
# 24  0.255516        (whole milk)
# 22  0.193493  (other vegetables)
# 53  0.183935        (rolls/buns)
# 99  0.174377              (soda)
# 29  0.139502            (yogurt)

# %%
#we are typically most interested in itemsets with multiple items in them (so we can find some sort of meaninful relation!)...

frequent_itemsets.iloc[0,1] #observe - this identifies a specific line from our df
# Out:
# frozenset({'frankfurter'})

# %%
len(frequent_itemsets.iloc[0,1]) #observe - this identifies the length of that line
# Out:
# 1

# %%
#create a length feature for our df
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))

# %%
#preview our df
frequent_itemsets.head()
# Out:
#     support       itemsets  length
# 0  0.058973  (frankfurter)       1
# 1  0.093950      (sausage)       1
# 2  0.005084   (liver loaf)       1
# 3  0.026029          (ham)       1
# 4  0.025826         (meat)       1

# %%
#now let's filter our frequent_itemsets df to cases where there were multiple items in the itemsets (i.e., len =2) and 
#that were pretty prevalent (i.e., support >= 0.02)

frequent_itemsets[(frequent_itemsets['length'] == 2) & (frequent_itemsets['support'] >= 0.02)]

#observations: we've returned 61 rows - all of relatively prevalent paired itemsets
# Out:
#        support                     itemsets  length
# 173   0.020539    (frankfurter, whole milk)       2
# 255   0.026945  (sausage, other vegetables)       2
# 257   0.029893        (sausage, whole milk)       2
# 281   0.030605        (sausage, rolls/buns)       2
# 303   0.024301              (sausage, soda)       2
# ...        ...                          ...     ...
# 2387  0.024199  (rolls/buns, bottled water)       2
# 2388  0.038332           (soda, rolls/buns)       2
# 2524  0.021047               (soda, pastry)       2
# 2856  0.028978        (soda, bottled water)       2
# 2928  0.024606        (shopping bags, soda)       2
#
# [61 rows x 3 columns]

# %%
#can search/isolate a specific itemset like this
frequent_itemsets[frequent_itemsets['itemsets'] == {'pastry', 'soda'}]
# Out:
#        support        itemsets  length
# 2524  0.021047  (soda, pastry)       2

# %%
#now let's find the association rules
from mlxtend.frequent_patterns import association_rules

rules = association_rules(frequent_itemsets, min_threshold=0.1) #note: here we've set the threshold to 0.1 (see notes for sig)

# %%
rules.info()

#observations: found 44,000 rules, 9 columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43732 entries, 0 to 43731
# Data columns (total 9 columns):
# antecedents           43732 non-null object
# consequents           43732 non-null object
# antecedent support    43732 non-null float64
# consequent support    43732 non-null float64
# support               43732 non-null float64
# confidence            43732 non-null float64
# lift                  43732 non-null float64
# leverage              43732 non-null float64
# conviction            43732 non-null float64
# dtypes: float64(7), object(2)
# memory usage: 3.0+ MB

# %%
#let's see these rules
rules.head()
# Out:
#         antecedents    consequents  antecedent support  consequent support  \
# 0     (frankfurter)      (sausage)            0.058973            0.093950
# 1         (sausage)  (frankfurter)            0.093950            0.058973
# 2            (meat)  (frankfurter)            0.025826            0.058973
# 3            (pork)  (frankfurter)            0.057651            0.058973
# 4  (hamburger meat)  (frankfurter)            0.033249            0.058973
#
#     support  confidence      lift  leverage  conviction
# 0  0.010066    0.170690  1.816810  0.004526    1.092534
# 1  0.010066    0.107143  1.816810  0.004526    1.053950
# 2  0.003254    0.125984  2.136302  0.001731    1.076670
# 3  0.005897    0.102293  1.734568  0.002497    1.048256
# 4  0.003355    0.100917  1.711246  0.001395    1.046652

# %%
#now it's just a matter of digging through these rules and finding something of interest!

rules['antecedent_len'] = rules['antecedents'].apply(lambda x: len(x)) #re-adding itemset length

# %%
rules.head()
# Out:
#         antecedents    consequents  antecedent support  consequent support  \
# 0     (frankfurter)      (sausage)            0.058973            0.093950
# 1         (sausage)  (frankfurter)            0.093950            0.058973
# 2            (meat)  (frankfurter)            0.025826            0.058973
# 3            (pork)  (frankfurter)            0.057651            0.058973
# 4  (hamburger meat)  (frankfurter)            0.033249            0.058973
#
#     support  confidence      lift  leverage  conviction  antecedent_len
# 0  0.010066    0.170690  1.816810  0.004526    1.092534               1
# 1  0.010066    0.107143  1.816810  0.004526    1.053950               1
# 2  0.003254    0.125984  2.136302  0.001731    1.076670               1
# 3  0.005897    0.102293  1.734568  0.002497    1.048256               1
# 4  0.003355    0.100917  1.711246  0.001395    1.046652               1

# %%
#show me all the rules that have at least 2 items in the itemset, a confidence of at least 75%, and a lift of at least 1.2
rules[(rules['antecedent_len'] >= 2) &
     (rules['confidence'] >= 0.75) &
     (rules['lift'] >= 1.2)].sort_values(by=['support'], ascending=False)

#observations: Has returned 783 rules that satisfy in our criteria above
# Out:
#                                              antecedents  \
# 24174    (citrus fruit, root vegetables, tropical fruit)
# 27997                     (curd, yogurt, tropical fruit)
# 30692   (brown bread, other vegetables, root vegetables)
# 38975  (whole milk, citrus fruit, root vegetables, tr...
# 12017                                   (butter, onions)
# ...                                                  ...
# 34389  (other vegetables, long life bakery product, s...
# 34167           (other vegetables, chocolate, margarine)
# 33592  (other vegetables, whipped/sour cream, detergent)
# 32853         (herbs, whole milk, fruit/vegetable juice)
# 43702    (yogurt, domestic eggs, butter, tropical fruit)
#
#                           consequents  antecedent support  consequent support  \
# 24174              (other vegetables)            0.005694            0.193493
# 27997                    (whole milk)            0.005287            0.255516
# 30692                    (whole milk)            0.004067            0.255516
# 38975              (other vegetables)            0.003559            0.193493
# 12017                    (whole milk)            0.004067            0.255516
# ...                               ...                 ...                 ...
# 34389                    (whole milk)            0.001220            0.255516
# 34167                    (whole milk)            0.001322            0.255516
# 33592                    (whole milk)            0.001220            0.255516
# 32853              (other vegetables)            0.001118            0.193493
# 43702  (other vegetables, whole milk)            0.001322            0.074835
#
#         support  confidence       lift  leverage  conviction  antecedent_len
# 24174  0.004474    0.785714   4.060694  0.003372    3.763701               3
# 27997  0.003965    0.750000   2.935237  0.002614    2.977936               3
# 30692  0.003152    0.775000   3.033078  0.002113    3.308818               3
# 38975  0.003152    0.885714   4.577509  0.002463    7.056940               4
# 12017  0.003050    0.750000   2.935237  0.002011    2.977936               2
# ...         ...         ...        ...       ...         ...             ...
# 34389  0.001017    0.833333   3.261374  0.000705    4.466904               3
# 34167  0.001017    0.769231   3.010499  0.000679    3.226097               3
# 33592  0.001017    0.833333   3.261374  0.000705    4.466904               3
# 32853  0.001017    0.909091   4.698323  0.000800    8.871581               3
# 43702  0.001017    0.769231  10.279055  0.000918    4.009049               4
#
# [783 rows x 10 columns]

# %%
#show me all the rules that contain yogurt
rules[rules['antecedents'].apply(lambda x: 'yogurt' in x)]

#observations: returns 7322 rules that include yogurt in their itemset
# Out:
#                                antecedents  \
# 78                                (yogurt)
# 393                               (yogurt)
# 486                               (yogurt)
# 596                               (yogurt)
# 711                               (yogurt)
# ...                                    ...
# 43718      (yogurt, domestic eggs, butter)
# 43719  (yogurt, domestic eggs, whole milk)
# 43725     (yogurt, butter, tropical fruit)
# 43726   (other vegetables, yogurt, butter)
# 43727         (yogurt, butter, whole milk)
#
#                                              consequents  antecedent support  \
# 78                                             (sausage)            0.139502
# 393                                       (citrus fruit)            0.139502
# 486                                     (tropical fruit)            0.139502
# 596                                          (pip fruit)            0.139502
# 711                                    (root vegetables)            0.139502
# ...                                                  ...                 ...
# 43718     (other vegetables, whole milk, tropical fruit)            0.002949
# 43719         (other vegetables, butter, tropical fruit)            0.007728
# 43725      (other vegetables, domestic eggs, whole milk)            0.004575
# 43726        (domestic eggs, whole milk, tropical fruit)            0.006406
# 43727  (other vegetables, domestic eggs, tropical fruit)            0.009354
#
#        consequent support   support  confidence       lift  leverage  \
# 78               0.093950  0.019624    0.140671   1.497289  0.006518
# 393              0.082766  0.021657    0.155248   1.875752  0.010111
# 486              0.104931  0.029283    0.209913   2.000475  0.014645
# 596              0.075648  0.017997    0.129009   1.705378  0.007444
# 711              0.108998  0.025826    0.185131   1.698475  0.010621
# ...                   ...       ...         ...        ...       ...
# 43718            0.017082  0.001017    0.344828  20.186782  0.000966
# 43719            0.005491  0.001017    0.131579  23.964425  0.000974
# 43725            0.012303  0.001017    0.222222  18.062443  0.000960
# 43726            0.006914  0.001017    0.158730  22.957516  0.000972
# 43727            0.004779  0.001017    0.108696  22.745143  0.000972
#
#        conviction  antecedent_len
# 78       1.054368               1
# 393      1.085803               1
# 486      1.132873               1
# 596      1.061264               1
# 711      1.093429               1
# ...           ...             ...
# 43718    1.500243               3
# 43719    1.145193               3
# 43725    1.269896               3
# 43726    1.180461               3
# 43727    1.116590               3
#
# [7322 rows x 10 columns]
